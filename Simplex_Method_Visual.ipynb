# %%
pip install gilp
# Out:
# ...
#      |████████████████████████████████| 81kB 7.6MB/s
# ...
#      |████████████████████████████████| 13.2MB 301kB/s
# ...
#      |████████████████████████████████| 327kB 32.8MB/s
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-cp37-none-any.whl size=26308 sha256=a16d25663a73cf49a8b75a9ded525f1becf2fada3a6add993474e6965625653d
#   Stored in directory: /root/.cache/pip/wheels/2d/04/41/8e1836e79581989c22eebac3f4e70aaac9af07b0908da173be
# ...
#   Created wheel for pyhull: filename=pyhull-2015.2.1-cp37-cp37m-linux_x86_64.whl size=444230 sha256=8573729aa62f0bb57a39d71f3a21896e16fa8d6bdcde9129dc3f5770f7ab1bb1
#   Stored in directory: /root/.cache/pip/wheels/ce/55/53/e62bbcc5daafc9ae4d09590581193249782445e0d73b878b74
# Successfully built typing pyhull
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %%
import numpy as np
from gilp.simplex import LP
from gilp.visualize import simplex_visual
from gilp import examples as ex

# %%
# User Defined Input

# Example Input
A = np.array([[0, 1], [1, -1],
              [1, 0],
              [-2, 1]])

b = np.array([4,2,3,0])

c = np.array([1,2])

lp = LP(A,b,c)

x = np.array([[0],[0],[0],[5],[25],[125]])
l = 7

# x = np.array([[0],[25],[25]])
simplex_visual(ex.DODECAHEDRON_3D_LP).show()
# simplex_visual(ex.KLEE_MINTY_3D_LP, initial_solution=x).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
A = np.array([[0, 1],
              [1, -1],
              [1, 0],
              [-2, 1]])
b = np.array([[4],
              [2],
              [3],
              [0]])
c = np.array([[1],
              [2]])

lp = LP(A,b,c)

x = np.array([[2],[0],[4],[0],[1],[4]])
l = 7

# simplex_visual(lp).show()
simplex_visual(lp, initial_solution=x).show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
